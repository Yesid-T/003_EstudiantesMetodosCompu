# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg #para poder mostrar imagenes
from scipy import interpolate
from scipy.interpolate import lagrange

# %matplotlib inline

# %%
ruta_imagen = "planetario.jpg"
imagen = mpimg.imread(ruta_imagen)  # Guarda la imagen en la variable

plt.figure(figsize=(8, 6))
plt.imshow(imagen)  # Muestra la imagen
plt.show()

# %%
x_ = np.array([332,335,340,348,357,369,386,409,433,456,486,514,538,569,595,622,666,689,710,725,737,744,745])
y_ = np.array([233,212,192,170,149,128,107,88,71,58,48,42,41,43,49,58,86,106,133,162,191,221,250])

# %%
# 1. Carguemos y mostremos la imagen
plt.figure(figsize=(8, 6))
imagen = plt.imread('planetario.jpg')
plt.imshow(imagen)
plt.plot(x_, y_, "ro")
plt.show()

# %%
x_ = np.array([332,348,369,386,433,456,514,569,595,666,710,737,745])
y_ = np.array([233,170,128,107,71,58,42,43,49,86,133,191,250])
# 1. Carguemos y mostremos la imagen
plt.figure(figsize=(8, 6))
imagen = plt.imread('planetario.jpg')
plt.imshow(imagen)
plt.plot(x_, y_, "ro")
plt.show()

# %%
plt.figure(figsize=(8, 6))
imagen = plt.imread('planetario.jpg')
plt.imshow(imagen)

for i in range(0,len(x_)-1,1):

  x=np.linspace(x_[i],x_[i+1],7)
  m=(y_[i+1]-y_[i])/(x_[i+1]-x_[i])
  y= m*(x-x_[i])+y_[i]

  plt.grid()
  plt.plot(x, y)

plt.show()
